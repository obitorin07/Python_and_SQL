# %%
import pandas as pd

dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,89,99,87,90,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female']
               }
df=pd.DataFrame(dict1)

# %% [markdown]
# # Display Top 3 Rows

# %%
df.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %% [markdown]
# ## Display Last 3 rows

# %%
df.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# ## Find shape of our dataset

# %%
df.shape
# Out:
# (7, 3)

# %% [markdown]
# ## dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# ## check null values in dataset

# %%
df.isna().sum()
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %% [markdown]
# ## display statistics about dataset

# %%
df.describe()
# Out:
#            Marks
# count   7.000000
# mean   92.142857
# std     6.491753
# min    83.000000
# 25%    88.000000
# 50%    90.000000
# 75%    98.500000
# max    99.000000

# %% [markdown]
# ## unique values from the Gender

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ## Find The Number of unique Genders in dataset

# %%
print('There Are ', df.Gender.nunique(),'Genders')
# Out:
# There Are  2 Genders

# %% [markdown]
# ## display how many people are in each gender

# %%
df.Gender.value_counts().reset_index()
# Out:
#    Gender  count
# 0  Female      4
# 1    Male      3

# %% [markdown]
# ## display students who's marks having between 90 to 100

# %%
df[(df.Marks >=90 ) & (df.Marks<=100)]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
## another method
df[df['Marks'].between(90,100)]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %% [markdown]
# ## average marks

# %%
df['Marks'].mean()
# Out:
# 92.14285714285714

# %% [markdown]
# ## sort data by marks in ascending order

# %%
df.sort_values(by='Marks',ascending =True)
# Out:
#       Name  Marks  Gender
# 5   Mittal     83  Female
# 3   Vedant     87    Male
# 1   Aadhya     89  Female
# 4   Parshv     90    Male
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 6  Archana     99  Female

# %% [markdown]
# ## display all columns

# %%
df.columns
# Out:
# Index(['Name', 'Marks', 'Gender'], dtype='object')

# %% [markdown]
# ## drop marks columns

# %%
df.drop(columns = ['Marks'], inplace= True)

# %%
df
# Out:
#       Name  Gender
# 0  Priyang    Male
# 1   Aadhya  Female
# 2   Krisha  Female
# 3   Vedant    Male
# 4   Parshv    Male
# 5   Mittal  Female
# 6  Archana  Female
